# %%
import cleandata

# %%
data='~/courses/metis/data/proj1/turnstile_210605.txt'

# %%
errcnt,df=cleandata.proj1_clean(data)
# Out:
# less than  42 data points40
# less than  42 data points40
# less than  42 data points40
# less than  42 data points40
# less than  42 data points40
# less than  42 data points40
# less than  42 data points40
# less than  42 data points40
# less than  42 data points40
# less than  42 data points40
# less than  42 data points40
# less than  42 data points40
# less than  42 data points40
# less than  42 data points40
# less than  42 data points40
# less than  42 data points40
# less than  42 data points40
# less than  42 data points40
# less than  42 data points40
# less than  42 data points40
# less than  42 data points40
# less than  42 data points40
# less than  42 data points40
# less than  42 data points40
# less than  42 data points40
# less than  42 data points40
# less than  42 data points36
# less than  42 data points45
# less than  42 data points45
# less than  42 data points45
# less than  42 data points45
# less than  42 data points45
# less than  42 data points45
# ...

# %%
errcnt
# Out:
# 850

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209531 entries, 0 to 209530
# Data columns (total 13 columns):
#  #   Column                                                                Non-Null Count   Dtype
# ---  ------                                                                --------------   -----
#  0   C/A                                                                   209531 non-null  object
#  1   UNIT                                                                  209531 non-null  object
#  2   SCP                                                                   209531 non-null  object
#  3   STATION                                                               209531 non-null  object
#  4   LINENAME                                                              209531 non-null  object
#  5   DIVISION                                                              209531 non-null  object
# ...

# %%
df[df['Ingress']==0]
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 0        A002  R051  02-00-00          59 ST  NQR456W      BMT  05/29/2021
# 31       A002  R051  02-00-00          59 ST  NQR456W      BMT  06/03/2021
# 37       A002  R051  02-00-00          59 ST  NQR456W      BMT  06/04/2021
# 42       A002  R051  02-00-01          59 ST  NQR456W      BMT  05/29/2021
# 61       A002  R051  02-00-01          59 ST  NQR456W      BMT  06/01/2021
# ...       ...   ...       ...            ...      ...      ...         ...
# 209526  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/04/2021
# 209527  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/04/2021
# 209528  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/04/2021
# 209529  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/04/2021
# 209530  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/04/2021
#
#             TIME     DESC  ENTRIES  \
# ...

# %%
len(df)/42
# Out:
# 4988.833333333333

# %%
df[(df['UNIT']=='R398') & (df['SCP'] == '01-06-01')]
# Out:
#         C/A  UNIT       SCP         STATION LINENAME DIVISION        DATE  \
# 26851  D006  R398  01-06-01  NEW UTRECHT AV       ND      BMT  05/29/2021
# 26852  D006  R398  01-06-01  NEW UTRECHT AV       ND      BMT  05/29/2021
# 26853  D006  R398  01-06-01  NEW UTRECHT AV       ND      BMT  05/29/2021
# 26854  D006  R398  01-06-01  NEW UTRECHT AV       ND      BMT  05/29/2021
# 26855  D006  R398  01-06-01  NEW UTRECHT AV       ND      BMT  05/29/2021
# ...     ...   ...       ...             ...      ...      ...         ...
# 26907  D006  R398  01-06-01  NEW UTRECHT AV       ND      BMT  06/04/2021
# 26908  D006  R398  01-06-01  NEW UTRECHT AV       ND      BMT  06/04/2021
# 26909  D006  R398  01-06-01  NEW UTRECHT AV       ND      BMT  06/04/2021
# 26910  D006  R398  01-06-01  NEW UTRECHT AV       ND      BMT  06/04/2021
# 26911  D006  R398  01-06-01  NEW UTRECHT AV       ND      BMT  06/04/2021
#
#            TIME        DESC  ENTRIES  \
# 26851  01:00:00     REGULAR  2764581
# ...

# %%
df.iloc[26856:26867]
# Out:
#         C/A  UNIT       SCP         STATION LINENAME DIVISION        DATE  \
# 26856  D006  R398  01-06-01  NEW UTRECHT AV       ND      BMT  05/29/2021
# 26857  D006  R398  01-06-01  NEW UTRECHT AV       ND      BMT  05/29/2021
# 26858  D006  R398  01-06-01  NEW UTRECHT AV       ND      BMT  05/29/2021
# 26859  D006  R398  01-06-01  NEW UTRECHT AV       ND      BMT  05/29/2021
# 26860  D006  R398  01-06-01  NEW UTRECHT AV       ND      BMT  05/29/2021
# 26861  D006  R398  01-06-01  NEW UTRECHT AV       ND      BMT  05/29/2021
# 26862  D006  R398  01-06-01  NEW UTRECHT AV       ND      BMT  05/29/2021
# 26863  D006  R398  01-06-01  NEW UTRECHT AV       ND      BMT  05/29/2021
# 26864  D006  R398  01-06-01  NEW UTRECHT AV       ND      BMT  05/29/2021
# 26865  D006  R398  01-06-01  NEW UTRECHT AV       ND      BMT  05/29/2021
# 26866  D006  R398  01-06-01  NEW UTRECHT AV       ND      BMT  05/29/2021
#
#            TIME     DESC  ENTRIES  \
# 26856  16:50:07  REGULAR  2764711
# ...
